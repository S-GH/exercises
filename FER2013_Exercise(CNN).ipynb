# %%
# 최신버전의 scipy는 toimage를 지원 하지 않아서 낮은 버전을 다운받는다.
# !pip install scipy==1.1.0

# colab setting
from google.colab import drive
drive.mount('/content/gdrive')

import pandas as pd
import numpy as np
from matplotlib import pyplot
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display
# %matplotlib inline

# 데이터셋 로드.
data= pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/fer2013.csv')
data.head()

# matplotlib.pylab의 rcParams 설정을 활용하면, 
# 차트의 크기와 선의 색, 두께등의 기본 값을 설정할 수 있다.
# 그림(figure)의 크기. (가로,세로) 인치 단위
from pylab import rcParams
rcParams['figure.figsize'] = 15, 10

# 정답 out put 7열
num_classes = 7

# 이미지 크기 전역변수 저장
width = 48
height = 48

# 0:분노 / 1:싫음 / 2:공포 / 3:행복 / 4:슬픔 / 5:놀람 / 6:중립
emotion_labels = ["Angry", "Disgust", "Fear", "Happy", "Sad", "Surprise", "Neutral"]
classes=np.array(("Angry", "Disgust", "Fear", "Happy", "Sad", "Surprise", "Neutral"))
data.Usage.value_counts() 

###### 정답 데이터 시각화 ######
depth = 1
height = int(sqrt(len(data.pixels[0].split()))) 
width = int(height)
for i in range(0, 10): 
    array = np.mat(data.pixels[i]).reshape(height, width) 
    image = scipy.misc.toimage(array, cmin=0.0)
    display(image)
    print(emotion_labels[data.emotion[i]]) 

## Dataset Split ##
train_set = data[(data.Usage == 'Training')] 
X_train = np.array(list(map(str.split, train_set.pixels)), np.float32) 
X_train = X_train.reshape(X_train.shape[0], 48, 48, 1)

val_set = data[(data.Usage == 'PublicTest')]
X_val = np.array(list(map(str.split, val_set.pixels)), np.float32) 
X_val = X_val.reshape(X_val.shape[0], 48, 48, 1)

test_set = data[(data.Usage == 'PrivateTest')] 
X_test = np.array(list(map(str.split, test_set.pixels)), np.float32) 
X_test = X_test.reshape(X_test.shape[0], 48, 48, 1)

# train, validation, test set 데이터 갯수
# train = 28709개
# val = 3589개
# test = 3589개
# image shape = 48*48*1
num_train = X_train.shape[0]
num_val = X_val.shape[0]
num_test = X_test.shape[0]

### one - hot incoding ###
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator 
y_train = train_set.emotion 
y_train = np_utils.to_categorical(y_train, num_classes) 
y_val = val_set.emotion 
y_val = np_utils.to_categorical(y_val, num_classes) 
y_test = test_set.emotion 
y_test = np_utils.to_categorical(y_test, num_classes)

########### ImageDataGenerator를 이용해서 데이터를 부풀린다. ############
datagen = ImageDataGenerator( 
    rescale=1./255,
    rotation_range = 10,
    horizontal_flip = True,
    width_shift_range=0.1,
    height_shift_range=0.1,
    fill_mode = 'nearest')

testgen = ImageDataGenerator( 
    rescale=1./255
    )
datagen.fit(X_train)
batch_size = 64

### ImageDataGenerator
train_flow = datagen.flow(X_train, y_train, batch_size=batch_size) 
val_flow = testgen.flow(X_val, y_val, batch_size=batch_size) 
test_flow = testgen.flow(X_test, y_test, batch_size=batch_size)
# Out:
# Collecting scipy==1.1.0
#   Downloading https://files.pythonhosted.org/packages/a8/0b/f163da98d3a01b3e0ef1cab8dd2123c34aee2bafbb1c5bffa354cc8a1730/scipy-1.1.0-cp36-cp36m-manylinux1_x86_64.whl (31.2MB)
#      |████████████████████████████████| 31.2MB 102kB/s
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.6/dist-packages (from scipy==1.1.0) (1.17.4)
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: scipy
#   Found existing installation: scipy 1.3.3
#     Uninstalling scipy-1.3.3:
#       Successfully uninstalled scipy-1.3.3
# Successfully installed scipy-1.1.0
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:44: DeprecationWarning: `toimage` is deprecated!
# `toimage` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use Pillow's ``Image.fromarray`` directly instead.
# <PIL.Image.Image image mode=L size=48x48 at 0x7FB22A55CA90>
# Angry
# <PIL.Image.Image image mode=L size=48x48 at 0x7FB229E58EB8>
# Angry
# <PIL.Image.Image image mode=L size=48x48 at 0x7FB229E49EB8>
# Fear
# <PIL.Image.Image image mode=L size=48x48 at 0x7FB229E020B8>
# Sad
# <PIL.Image.Image image mode=L size=48x48 at 0x7FB229E13400>
# Neutral
# <PIL.Image.Image image mode=L size=48x48 at 0x7FB229E58EF0>
# Fear
# <PIL.Image.Image image mode=L size=48x48 at 0x7FB229E01080>
# Sad
# <PIL.Image.Image image mode=L size=48x48 at 0x7FB229E497F0>
# Happy
# <PIL.Image.Image image mode=L size=48x48 at 0x7FB229E021D0>
# Happy
# <PIL.Image.Image image mode=L size=48x48 at 0x7FB229DFB080>
# Fear
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
from tensorflow.keras import models, layers, activations, initializers, losses, optimizers, metrics
from keras.regularizers import l1, l2
from matplotlib import pyplot as plt


num_features = 64
num_labels = 7
width, height = 48, 48

model = models.Sequential()


################ MODEL START ###################
# input 
model.add(layers.Conv2D(num_features, kernel_size=3, activation='relu', input_shape=(width, height, 1), data_format='channels_last', kernel_regularizer=l2(0.01)))

################ HIDDEN L1 ###################
model.add(layers.Conv2D(num_features, kernel_size=3, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(num_features, kernel_size=3, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.3))

################ HIDDEN L2 ###################
model.add(layers.Conv2D(2*num_features, kernel_size=3, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(2*num_features, kernel_size=3, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(2*num_features, kernel_size=3, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.3))

################ HIDDEN L3 ###################
model.add(layers.Conv2D(2*2*num_features, kernel_size=3, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(2*2*num_features, kernel_size=3, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(2*2*num_features, kernel_size=3, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(2*2*num_features, kernel_size=3, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.3))

################ HIDDEN L4 ###################
model.add(layers.Conv2D(2*2*num_features, kernel_size=3, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(2*2*num_features, kernel_size=3, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(2*2*num_features, kernel_size=3, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(2*2*num_features, kernel_size=3, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.3))

################ HIDDEN L5 ###################
model.add(layers.Conv2D(2*2*2*num_features, kernel_size=3, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(2*2*2*num_features, kernel_size=3, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(2*2*2*num_features, kernel_size=3, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(2*2*2*num_features, kernel_size=3, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.3))

################ OUT PUT ###################
model.add(layers.Flatten())
model.add(layers.Dense(num_labels, activation='softmax'))


# bet_1, beta_2 = 모멘텀과 관련된 파라미터.
# decay = learning late 점점 줄여주는 비율
model.compile(loss=losses.categorical_crossentropy,
              optimizer=optimizers.Adam(lr=0.0001, decay=1e-6),
              #optimizer=optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-7, decay=1e-6),
              metrics=['accuracy'])

# 모델 저장 callback 함수
from keras.callbacks import ModelCheckpoint
filepath="weight_minloss.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

# training the model
# 하이퍼 파라미터
# steps_per_epoch = 한 번 epoch 돌 때, 데이터를 몇 번 볼 것인가를 정해준다.
# verbose = 2 주피터 노트북 전용 옵션, callbacks = 모델 저장 옵션을 지정
num_epochs = 100
history = model.fit_generator(train_flow, 
                    steps_per_epoch=len(X_train) / batch_size, 
                    epochs=num_epochs,  
                    verbose=2,  
                    callbacks=callbacks_list,
                    validation_data=val_flow,  
                    validation_steps=len(X_val) / batch_size)

# %matplotlib inline

train_loss=history.history['loss']
val_loss=history.history['val_loss']
train_acc=history.history['acc']
val_acc=history.history['val_acc']

epochs = range(len(train_acc))

### echoc 정확도 변화 시각화 ###
plt.plot(epochs,train_loss,'r', label='train_loss')
plt.plot(epochs,val_loss,'b', label='val_loss')
plt.title('train_loss vs val_loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
plt.figure()

plt.plot(epochs,train_acc,'r', label='train_acc')
plt.plot(epochs,val_acc,'b', label='val_acc')
plt.title('train_acc vs val_acc')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend()
plt.figure()

# flow data를 평가해주는 함수 evaluate_generator로 테스트 데이터셋 최종 정확도 출력
loss = model.evaluate_generator(test_flow, steps=len(X_test) / batch_size) 
print("Test Loss " + str(loss[0]))
print("Test Acc: " + str(loss[1]))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Epoch 1/100
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 1.98931, saving model to weight_minloss.hdf5
# 449/448 - 37s - loss: 2.5456 - acc: 0.2103 - val_loss: 1.9893 - val_acc: 0.2477
# Epoch 2/100
# Epoch 1/100
#
# Epoch 00002: val_loss did not improve from 1.98931
# 449/448 - 24s - loss: 2.1245 - acc: 0.2431 - val_loss: 2.0082 - val_acc: 0.2257
# Epoch 3/100
# Epoch 1/100
#
# Epoch 00003: val_loss improved from 1.98931 to 1.92609, saving model to weight_minloss.hdf5
# 449/448 - 25s - loss: 2.0703 - acc: 0.2565 - val_loss: 1.9261 - val_acc: 0.2708
# Epoch 4/100
# Epoch 1/100
#
# Epoch 00004: val_loss improved from 1.92609 to 1.80757, saving model to weight_minloss.hdf5
# 449/448 - 25s - loss: 1.9916 - acc: 0.2825 - val_loss: 1.8076 - val_acc: 0.3383
# Epoch 5/100
# Epoch 1/100
#
# Epoch 00005: val_loss did not improve from 1.80757
# 449/448 - 24s - loss: 1.9025 - acc: 0.3186 - val_loss: 2.5978 - val_acc: 0.2572
# Epoch 6/100
# Epoch 1/100
#
# Epoch 00006: val_loss did not improve from 1.80757
# 449/448 - 24s - loss: 1.8685 - acc: 0.3484 - val_loss: 1.8118 - val_acc: 0.3675
# Epoch 7/100
# Epoch 1/100
#
# Epoch 00007: val_loss improved from 1.80757 to 1.74708, saving model to weight_minloss.hdf5
# 449/448 - 25s - loss: 1.7932 - acc: 0.3771 - val_loss: 1.7471 - val_acc: 0.4113
# Epoch 8/100
# Epoch 1/100
#
# Epoch 00008: val_loss improved from 1.74708 to 1.61478, saving model to weight_minloss.hdf5
# 449/448 - 25s - loss: 1.7317 - acc: 0.4043 - val_loss: 1.6148 - val_acc: 0.4277
# Epoch 9/100
# Epoch 1/100
#
# Epoch 00009: val_loss did not improve from 1.61478
# 449/448 - 24s - loss: 1.6959 - acc: 0.4097 - val_loss: 2.3210 - val_acc: 0.3182
# Epoch 10/100
# Epoch 1/100
#
# Epoch 00010: val_loss did not improve from 1.61478
# 449/448 - 24s - loss: 1.6275 - acc: 0.4377 - val_loss: 1.7556 - val_acc: 0.4046
# Epoch 11/100
# Epoch 1/100
#
# Epoch 00011: val_loss improved from 1.61478 to 1.56352, saving model to weight_minloss.hdf5
# 449/448 - 25s - loss: 1.5837 - acc: 0.4531 - val_loss: 1.5635 - val_acc: 0.4664
# Epoch 12/100
# Epoch 1/100
#
# Epoch 00012: val_loss improved from 1.56352 to 1.55093, saving model to weight_minloss.hdf5
# 449/448 - 25s - loss: 1.5313 - acc: 0.4725 - val_loss: 1.5509 - val_acc: 0.4313
# Epoch 13/100
# Epoch 1/100
#
# Epoch 00013: val_loss improved from 1.55093 to 1.37277, saving model to weight_minloss.hdf5
# 449/448 - 25s - loss: 1.4127 - acc: 0.4819 - val_loss: 1.3728 - val_acc: 0.4890
# Epoch 14/100
# Epoch 1/100
#
# Epoch 00014: val_loss improved from 1.37277 to 1.36500, saving model to weight_minloss.hdf5
# 449/448 - 25s - loss: 1.3107 - acc: 0.5104 - val_loss: 1.3650 - val_acc: 0.4976
# Epoch 15/100
# Epoch 1/100
#
# Epoch 00015: val_loss did not improve from 1.36500
# 449/448 - 24s - loss: 1.2738 - acc: 0.5223 - val_loss: 1.3806 - val_acc: 0.5486
# Epoch 16/100
# Epoch 1/100
#
# Epoch 00016: val_loss improved from 1.36500 to 1.22715, saving model to weight_minloss.hdf5
# 449/448 - 25s - loss: 1.2529 - acc: 0.5323 - val_loss: 1.2272 - val_acc: 0.5461
# Epoch 17/100
# Epoch 1/100
#
# Epoch 00017: val_loss improved from 1.22715 to 1.21396, saving model to weight_minloss.hdf5
# 449/448 - 25s - loss: 1.2233 - acc: 0.5432 - val_loss: 1.2140 - val_acc: 0.5506
# Epoch 18/100
# Epoch 1/100
#
# Epoch 00018: val_loss did not improve from 1.21396
# 449/448 - 24s - loss: 1.2041 - acc: 0.5569 - val_loss: 1.2767 - val_acc: 0.5492
# Epoch 19/100
# Epoch 1/100
#
# Epoch 00019: val_loss improved from 1.21396 to 1.14063, saving model to weight_minloss.hdf5
# 449/448 - 25s - loss: 1.1786 - acc: 0.5647 - val_loss: 1.1406 - val_acc: 0.5695
# Epoch 20/100
# Epoch 1/100
#
# Epoch 00020: val_loss did not improve from 1.14063
# 449/448 - 24s - loss: 1.1534 - acc: 0.5707 - val_loss: 1.1792 - val_acc: 0.5678
# Epoch 21/100
# Epoch 1/100
#
# Epoch 00021: val_loss improved from 1.14063 to 1.11419, saving model to weight_minloss.hdf5
# 449/448 - 25s - loss: 1.1408 - acc: 0.5783 - val_loss: 1.1142 - val_acc: 0.5860
# Epoch 22/100
# Epoch 1/100
#
# Epoch 00022: val_loss did not improve from 1.11419
# 449/448 - 24s - loss: 1.1067 - acc: 0.5919 - val_loss: 1.1521 - val_acc: 0.5762
# Epoch 23/100
# Epoch 1/100
#
# Epoch 00023: val_loss did not improve from 1.11419
# 449/448 - 24s - loss: 1.1145 - acc: 0.5904 - val_loss: 1.1331 - val_acc: 0.5795
# Epoch 24/100
# Epoch 1/100
#
# Epoch 00024: val_loss did not improve from 1.11419
# 449/448 - 24s - loss: 1.1274 - acc: 0.5810 - val_loss: 1.1407 - val_acc: 0.5809
# Epoch 25/100
# Epoch 1/100
#
# Epoch 00025: val_loss did not improve from 1.11419
# 449/448 - 24s - loss: 1.0723 - acc: 0.6017 - val_loss: 1.2119 - val_acc: 0.5575
# Epoch 26/100
# Epoch 1/100
#
# Epoch 00026: val_loss improved from 1.11419 to 1.08978, saving model to weight_minloss.hdf5
# 449/448 - 25s - loss: 1.1493 - acc: 0.5782 - val_loss: 1.0898 - val_acc: 0.6010
# Epoch 27/100
# Epoch 1/100
#
# Epoch 00027: val_loss did not improve from 1.08978
# 449/448 - 24s - loss: 1.0591 - acc: 0.6052 - val_loss: 1.0899 - val_acc: 0.6052
# Epoch 28/100
# Epoch 1/100
#
# Epoch 00028: val_loss improved from 1.08978 to 1.07359, saving model to weight_minloss.hdf5
# 449/448 - 25s - loss: 1.0409 - acc: 0.6160 - val_loss: 1.0736 - val_acc: 0.6158
# Epoch 29/100
# Epoch 1/100
#
# Epoch 00029: val_loss did not improve from 1.07359
# 449/448 - 24s - loss: 1.0286 - acc: 0.6228 - val_loss: 1.1941 - val_acc: 0.5545
# Epoch 30/100
# Epoch 1/100
#
# Epoch 00030: val_loss improved from 1.07359 to 1.06666, saving model to weight_minloss.hdf5
# 449/448 - 25s - loss: 1.0225 - acc: 0.6197 - val_loss: 1.0667 - val_acc: 0.6124
# Epoch 31/100
# Epoch 1/100
#
# Epoch 00031: val_loss improved from 1.06666 to 1.06474, saving model to weight_minloss.hdf5
# 449/448 - 25s - loss: 1.0317 - acc: 0.6174 - val_loss: 1.0647 - val_acc: 0.6141
# Epoch 32/100
# Epoch 1/100
#
# Epoch 00032: val_loss improved from 1.06474 to 1.05808, saving model to weight_minloss.hdf5
# 449/448 - 25s - loss: 1.0044 - acc: 0.6285 - val_loss: 1.0581 - val_acc: 0.6194
# Epoch 33/100
# Epoch 1/100
#
# Epoch 00033: val_loss improved from 1.05808 to 1.02846, saving model to weight_minloss.hdf5
# 449/448 - 25s - loss: 1.0060 - acc: 0.6284 - val_loss: 1.0285 - val_acc: 0.6239
# Epoch 34/100
# Epoch 1/100
#
# Epoch 00034: val_loss did not improve from 1.02846
# 449/448 - 24s - loss: 0.9735 - acc: 0.6401 - val_loss: 1.0912 - val_acc: 0.6071
# Epoch 35/100
# Epoch 1/100
#
# Epoch 00035: val_loss did not improve from 1.02846
# 449/448 - 24s - loss: 0.9548 - acc: 0.6476 - val_loss: 1.2962 - val_acc: 0.5391
# Epoch 36/100
# Epoch 1/100
#
# Epoch 00036: val_loss did not improve from 1.02846
# 449/448 - 24s - loss: 0.9733 - acc: 0.6393 - val_loss: 1.0520 - val_acc: 0.6166
# Epoch 37/100
# Epoch 1/100
#
# Epoch 00037: val_loss did not improve from 1.02846
# 449/448 - 24s - loss: 0.9558 - acc: 0.6482 - val_loss: 1.0330 - val_acc: 0.6350
# Epoch 38/100
# Epoch 1/100
#
# Epoch 00038: val_loss did not improve from 1.02846
# 449/448 - 24s - loss: 0.9270 - acc: 0.6594 - val_loss: 1.0402 - val_acc: 0.6166
# Epoch 39/100
# Epoch 1/100
#
# Epoch 00039: val_loss improved from 1.02846 to 1.01674, saving model to weight_minloss.hdf5
# 449/448 - 25s - loss: 0.9332 - acc: 0.6574 - val_loss: 1.0167 - val_acc: 0.6392
# Epoch 40/100
# Epoch 1/100
#
# Epoch 00040: val_loss did not improve from 1.01674
# 449/448 - 24s - loss: 0.9243 - acc: 0.6612 - val_loss: 1.0690 - val_acc: 0.6289
# Epoch 41/100
# Epoch 1/100
#
# Epoch 00041: val_loss did not improve from 1.01674
# 449/448 - 24s - loss: 0.8989 - acc: 0.6684 - val_loss: 1.0213 - val_acc: 0.6353
# Epoch 42/100
# Epoch 1/100
#
# Epoch 00042: val_loss did not improve from 1.01674
# 449/448 - 24s - loss: 0.8916 - acc: 0.6703 - val_loss: 1.0200 - val_acc: 0.6411
# Epoch 43/100
# Epoch 1/100
#
# Epoch 00043: val_loss improved from 1.01674 to 1.00503, saving model to weight_minloss.hdf5
# 449/448 - 25s - loss: 0.9119 - acc: 0.6646 - val_loss: 1.0050 - val_acc: 0.6347
# Epoch 44/100
# Epoch 1/100
#
# Epoch 00044: val_loss did not improve from 1.00503
# 449/448 - 24s - loss: 0.8886 - acc: 0.6725 - val_loss: 1.0056 - val_acc: 0.6453
# Epoch 45/100
# Epoch 1/100
#
# Epoch 00045: val_loss improved from 1.00503 to 0.99215, saving model to weight_minloss.hdf5
# 449/448 - 25s - loss: 0.8611 - acc: 0.6822 - val_loss: 0.9921 - val_acc: 0.6500
# Epoch 46/100
# Epoch 1/100
#
# Epoch 00046: val_loss did not improve from 0.99215
# 449/448 - 24s - loss: 0.8875 - acc: 0.6731 - val_loss: 1.0092 - val_acc: 0.6372
# Epoch 47/100
# Epoch 1/100
#
# Epoch 00047: val_loss did not improve from 0.99215
# 449/448 - 24s - loss: 0.8400 - acc: 0.6899 - val_loss: 1.0523 - val_acc: 0.6294
# Epoch 48/100
# Epoch 1/100
#
# Epoch 00048: val_loss did not improve from 0.99215
# 449/448 - 24s - loss: 0.8376 - acc: 0.6945 - val_loss: 1.0679 - val_acc: 0.6283
# Epoch 49/100
# Epoch 1/100
#
# Epoch 00049: val_loss did not improve from 0.99215
# 449/448 - 24s - loss: 0.8133 - acc: 0.7001 - val_loss: 1.0067 - val_acc: 0.6478
# Epoch 50/100
# Epoch 1/100
#
# Epoch 00050: val_loss did not improve from 0.99215
# 449/448 - 24s - loss: 0.8168 - acc: 0.7021 - val_loss: 0.9958 - val_acc: 0.6467
# Epoch 51/100
# Epoch 1/100
#
# Epoch 00051: val_loss did not improve from 0.99215
# 449/448 - 24s - loss: 0.8069 - acc: 0.7040 - val_loss: 1.0071 - val_acc: 0.6545
# Epoch 52/100
# Epoch 1/100
#
# Epoch 00052: val_loss did not improve from 0.99215
# 449/448 - 24s - loss: 0.7884 - acc: 0.7108 - val_loss: 1.0269 - val_acc: 0.6314
# Epoch 53/100
# Epoch 1/100
#
# Epoch 00053: val_loss did not improve from 0.99215
# 449/448 - 24s - loss: 0.7781 - acc: 0.7140 - val_loss: 1.0017 - val_acc: 0.6473
# Epoch 54/100
# Epoch 1/100
#
# Epoch 00054: val_loss did not improve from 0.99215
# 449/448 - 24s - loss: 0.7691 - acc: 0.7174 - val_loss: 1.0092 - val_acc: 0.6411
# Epoch 55/100
# Epoch 1/100
#
# Epoch 00055: val_loss did not improve from 0.99215
# 449/448 - 24s - loss: 0.7759 - acc: 0.7191 - val_loss: 1.0042 - val_acc: 0.6467
# Epoch 56/100
# Epoch 1/100
#
# Epoch 00056: val_loss improved from 0.99215 to 0.97639, saving model to weight_minloss.hdf5
# 449/448 - 25s - loss: 0.7569 - acc: 0.7225 - val_loss: 0.9764 - val_acc: 0.6584
# Epoch 57/100
# Epoch 1/100
#
# Epoch 00057: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.7474 - acc: 0.7263 - val_loss: 0.9836 - val_acc: 0.6598
# Epoch 58/100
# Epoch 1/100
#
# Epoch 00058: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.7279 - acc: 0.7332 - val_loss: 1.0252 - val_acc: 0.6486
# Epoch 59/100
# Epoch 1/100
#
# Epoch 00059: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.7237 - acc: 0.7366 - val_loss: 1.0002 - val_acc: 0.6484
# Epoch 60/100
# Epoch 1/100
#
# Epoch 00060: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.7052 - acc: 0.7429 - val_loss: 1.0201 - val_acc: 0.6528
# Epoch 61/100
# Epoch 1/100
#
# Epoch 00061: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.7048 - acc: 0.7437 - val_loss: 1.0042 - val_acc: 0.6676
# Epoch 62/100
# Epoch 1/100
#
# Epoch 00062: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.7186 - acc: 0.7411 - val_loss: 1.0368 - val_acc: 0.6486
# Epoch 63/100
# Epoch 1/100
#
# Epoch 00063: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.6884 - acc: 0.7500 - val_loss: 1.0366 - val_acc: 0.6615
# Epoch 64/100
# Epoch 1/100
#
# Epoch 00064: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.6745 - acc: 0.7518 - val_loss: 1.0984 - val_acc: 0.6559
# Epoch 65/100
# Epoch 1/100
#
# Epoch 00065: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.6884 - acc: 0.7486 - val_loss: 1.0093 - val_acc: 0.6514
# Epoch 66/100
# Epoch 1/100
#
# Epoch 00066: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.6522 - acc: 0.7644 - val_loss: 1.0008 - val_acc: 0.6662
# Epoch 67/100
# Epoch 1/100
#
# Epoch 00067: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.6587 - acc: 0.7588 - val_loss: 1.0342 - val_acc: 0.6587
# Epoch 68/100
# Epoch 1/100
#
# Epoch 00068: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.6447 - acc: 0.7660 - val_loss: 1.0346 - val_acc: 0.6551
# Epoch 69/100
# Epoch 1/100
#
# Epoch 00069: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.6222 - acc: 0.7737 - val_loss: 1.0137 - val_acc: 0.6709
# Epoch 70/100
# Epoch 1/100
#
# Epoch 00070: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.6167 - acc: 0.7754 - val_loss: 1.0103 - val_acc: 0.6604
# Epoch 71/100
# Epoch 1/100
#
# Epoch 00071: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.6292 - acc: 0.7741 - val_loss: 1.1149 - val_acc: 0.6592
# Epoch 72/100
# Epoch 1/100
#
# Epoch 00072: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.5956 - acc: 0.7832 - val_loss: 1.0522 - val_acc: 0.6606
# Epoch 73/100
# Epoch 1/100
#
# Epoch 00073: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.5864 - acc: 0.7855 - val_loss: 1.1171 - val_acc: 0.6500
# Epoch 74/100
# Epoch 1/100
#
# Epoch 00074: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.5826 - acc: 0.7893 - val_loss: 1.0425 - val_acc: 0.6609
# Epoch 75/100
# Epoch 1/100
#
# Epoch 00075: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.5796 - acc: 0.7899 - val_loss: 1.0659 - val_acc: 0.6643
# Epoch 76/100
# Epoch 1/100
#
# Epoch 00076: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.5667 - acc: 0.7938 - val_loss: 1.0515 - val_acc: 0.6509
# Epoch 77/100
# Epoch 1/100
#
# Epoch 00077: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.5475 - acc: 0.7998 - val_loss: 1.0844 - val_acc: 0.6679
# Epoch 78/100
# Epoch 1/100
#
# Epoch 00078: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.5628 - acc: 0.7976 - val_loss: 2.8303 - val_acc: 0.5731
# Epoch 79/100
# Epoch 1/100
#
# Epoch 00079: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.6046 - acc: 0.7807 - val_loss: 1.0836 - val_acc: 0.6531
# Epoch 80/100
# Epoch 1/100
#
# Epoch 00080: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.5344 - acc: 0.8065 - val_loss: 1.0687 - val_acc: 0.6732
# Epoch 81/100
# Epoch 1/100
#
# Epoch 00081: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.5286 - acc: 0.8087 - val_loss: 1.1143 - val_acc: 0.6567
# Epoch 82/100
# Epoch 1/100
#
# Epoch 00082: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.5220 - acc: 0.8115 - val_loss: 1.1419 - val_acc: 0.6525
# Epoch 83/100
# Epoch 1/100
#
# Epoch 00083: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.5117 - acc: 0.8152 - val_loss: 1.1575 - val_acc: 0.6643
# Epoch 84/100
# Epoch 1/100
#
# Epoch 00084: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.4939 - acc: 0.8225 - val_loss: 1.1356 - val_acc: 0.6679
# Epoch 85/100
# Epoch 1/100
#
# Epoch 00085: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.4935 - acc: 0.8196 - val_loss: 1.1481 - val_acc: 0.6570
# Epoch 86/100
# Epoch 1/100
#
# Epoch 00086: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.4896 - acc: 0.8244 - val_loss: 1.0950 - val_acc: 0.6732
# Epoch 87/100
# Epoch 1/100
#
# Epoch 00087: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.4848 - acc: 0.8256 - val_loss: 1.1134 - val_acc: 0.6684
# Epoch 88/100
# Epoch 1/100
#
# Epoch 00088: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.4743 - acc: 0.8279 - val_loss: 1.1493 - val_acc: 0.6651
# Epoch 89/100
# Epoch 1/100
#
# Epoch 00089: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.4632 - acc: 0.8304 - val_loss: 1.1610 - val_acc: 0.6556
# Epoch 90/100
# Epoch 1/100
#
# Epoch 00090: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.4600 - acc: 0.8345 - val_loss: 1.1351 - val_acc: 0.6732
# Epoch 91/100
# Epoch 1/100
#
# Epoch 00091: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.4567 - acc: 0.8351 - val_loss: 1.1343 - val_acc: 0.6665
# Epoch 92/100
# Epoch 1/100
#
# Epoch 00092: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.4445 - acc: 0.8387 - val_loss: 1.1349 - val_acc: 0.6726
# Epoch 93/100
# Epoch 1/100
#
# Epoch 00093: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.4432 - acc: 0.8409 - val_loss: 1.1381 - val_acc: 0.6715
# Epoch 94/100
# Epoch 1/100
#
# Epoch 00094: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.4273 - acc: 0.8462 - val_loss: 1.2106 - val_acc: 0.6643
# Epoch 95/100
# Epoch 1/100
#
# Epoch 00095: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.4281 - acc: 0.8445 - val_loss: 1.1903 - val_acc: 0.6604
# Epoch 96/100
# Epoch 1/100
#
# Epoch 00096: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.4170 - acc: 0.8483 - val_loss: 1.2041 - val_acc: 0.6673
# Epoch 97/100
# Epoch 1/100
#
# Epoch 00097: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.4164 - acc: 0.8505 - val_loss: 1.1594 - val_acc: 0.6732
# Epoch 98/100
# Epoch 1/100
#
# Epoch 00098: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.4029 - acc: 0.8548 - val_loss: 1.2482 - val_acc: 0.6640
# Epoch 99/100
# Epoch 1/100
#
# Epoch 00099: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.3997 - acc: 0.8568 - val_loss: 1.2080 - val_acc: 0.6782
# Epoch 100/100
# Epoch 1/100
#
# Epoch 00100: val_loss did not improve from 0.97639
# 449/448 - 24s - loss: 0.3945 - acc: 0.8581 - val_loss: 1.2143 - val_acc: 0.6651
# Test Loss 1.1346232958177431
# Test Acc: 0.68682086
